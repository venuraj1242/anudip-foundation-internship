# %% [markdown]
# ## Pie Plot
#
# Pie plots are commonly used to visualize data with clear categorical distinctions, such
# as:
# ●
# Market share of different products or companies.
# ●
# Budget allocation in various spending categories.
# ●
# Demographic breakdowns, such as age groups in a population.
# ●
# The composition of a portfolio's investments.
# ●
# Distribution of survey responses in various answer choices.

# %%
import matplotlib.pyplot as plt
# Market share data
manufacturers = ['Samsung', 'Apple', 'Huawei', 'Xiaomi', 'Others']
market_share = [30, 25, 18, 12, 15]
# Colors for each slice
colors = ['lightblue', 'lightcoral', 'lightgreen', 'lightpink', 'lightgrey']
# Create a pie chart
plt.pie(market_share, labels=manufacturers, colors=colors, autopct='%1.1f%%')

# Title
plt.title('Smartphone Market Share')
# Show the pie chart
plt.show()

# %% [markdown]
# ##  Scatter plot
# A scatter plot is a data visualization technique that is used to display individual data
# points on a two-dimensional graph. In a scatter plot, each data point represents one
# observation or data entry and is plotted as a point on the graph. The position of each
# point is determined by its values on two variables, typically referred to as the x-axis and
# y-axis.
# Scatter plots are valuable for various data analysis tasks, including:
# ●
# Visualizing relationships between variables (e.g., examining the relationship
# between a person's age and their income).
# ●
# Identifying clusters or patterns in data (e.g., detecting groupings of data points
# with similar characteristics).
# ●
# Detecting outliers or anomalies (e.g., identifying data points that deviate
# significantly from the norm).

# %%
import matplotlib.pyplot as plt
# Student data (study hours and exam scores)
study_hours = [2, 3, 1, 4, 3, 5, 2, 6, 5, 7]
exam_scores = [65, 75, 60, 80, 70, 85, 70, 90, 88, 92]
# Create a scatter plot
plt.scatter(study_hours, exam_scores, c='green', marker='o', label='Student Data',s=150,edgecolors="r")
# Labeling and Title
plt.xlabel('Study Hours')
plt.ylabel('Exam Scores')
plt.title('Study Hours vs. Exam Scores')
# Show the scatter plot
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ###  Subplot
# In data visualization, a subplot, short for "sub-plot," refers to a feature or capability that
# allows you to create multiple smaller plots within a single, larger plot or figure. Subplots
# are commonly used when you want to display multiple graphs or charts side by side,
# making it easier to compare and analyze different aspects of your data within a single
# visual representation.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Sample student data
students = ['Jhon', 'Smith', 'Marry', 'Rose', 'Devid']
math_scores = [85, 92, 78, 88, 90]
science_scores = [76, 88, 92, 80, 78]
# Create a subplot with two subplots (1 row, 2 columns)
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
# Plot Math Scores
axs[0].bar(students, math_scores, color='b')
axs[0].set_title('Math Scores')
axs[0].set_xlabel('Students')
axs[0].set_ylabel('Score')
# Plot Science Scores
axs[1].bar(students, science_scores, color='g')
axs[1].set_title('Science Scores')
axs[1].set_xlabel('Students')
axs[1].set_ylabel('Score')
# Adjust spacing between subplots
plt.tight_layout()
# Show the subplot
plt.show()

# %% [markdown]
# ## method two

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40, 50, 60, 70, 80, 90]
y = [1, 2, 3, 7, 5, 6, 7, 8, 9]
plt.subplot(2, 3, 1)
plt.plot(x, y, color="g")

plt.subplot(2, 3, 2)
plt.pie([1],colors="r")

plt.subplot(2, 3, 3)
a = [20, 40, 60]
plt.pie(a)

plt.subplot(2, 3, 4)
a1 = ["r", "a", "h", "u"]
a2 = [20, 40, 60, 80]
plt.bar(a1, a2)
plt.tight_layout()
plt.show()

# %% [markdown]
# text , annotate, legend

# %%
import matplotlib.pyplot as plt

# Sample data

x = [1, 2, 3, 4, 5]

y = [2, 3, 5, 7, 11]

#Creating plot

plt.plot(x, y)

#Adding title and axis Labels

plt.title('Plot with General Text')

plt.xlabel('X-axis')

plt.ylabel('Y-axis')

#Adding general text

plt.text(2, 6, 'Language', fontsize=10, color='white', bbox={"facecolor": "red"})
plt.annotate('Java', xy=(4, 8), xytext=(2, 10), arrowprops=dict(facecolor='yellow', shrink=0.1), fontsize=12, color='red')

# Create a legend
plt.legend(["Java"], loc=5, facecolor="yellow", edgecolor="red", framealpha=0.9, shadow=True)

plt.show()

# %% [markdown]
# Matplotlib provides several functions to customize the appearance of the axes in a plot. These include setting the ticks and limits for both the x-axis and y-axis. Here's how you can use ticks, yticks, xlim, and ylim in Matplotlib, along with some practical examples. xticks and yticks: These functions are used to get or set the current tick locations and labels of the x-axis and y-axis, respectively.
# 1 xlim and ylim: These functions are used to get or set the current x-axis and y-axis limits, respectively.

# %%
import matplotlib.pyplot as plt
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y)
plt.xlim(0,10)
plt.ylim(0, 12)
plt.show()

# %% [markdown]
#  xticks nad yticks

# %%
import matplotlib.pyplot as plt
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y)
plt.xticks([1,2,3,4,5],['one','two','three','four','five'])
plt.yticks([2,4,6,8,10,12],['two','four','six','eight','ten','twelve'])
plt.xlim(0,10)
plt.ylim(0, 12)

plt.show()

# %% [markdown]
# how to save chart

# %%
import matplotlib.pyplot as plt
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]
plt.plot(x, y)
plt.xticks([1,2,3,4,5],['one','two','three','four','five'])
plt.yticks([2,4,6,8,10,12],['two','four','six','eight','ten','twelve'])
plt.xlim(0,10)
plt.ylim(0, 12)
# plt.savefig("line_chart.png")
plt.savefig("line_chart.png",facecolor="red",transparent=True,bbox_inches="tight")
plt.savefig("high_res_linechart.png",dpi=300)
plt.show()

# %% [markdown]
# Exercise
# Use GPT to write a program:
# 1.Hi! Suppose I have sales data for a company, and I want to create a single figure
# with subplots to compare sales figures for different regions over time. Each subplot will
# represent a different region.Can you please generate a program on it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your data)
data = {'region': ['North', 'South', 'East', 'West'] * 25,
        'date': pd.date_range(start='2023-01-01', periods=100),
        'sales': np.random.randint(100, 1000, 100)}
df = pd.DataFrame(data)

# Group data by region
grouped_data = df.groupby('region')

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
axes = axes.flatten()

# Plot sales for each region
for i, (region, group) in enumerate(grouped_data):
    group.plot(x='date', y='sales', ax=axes[i], title=region, style='-o')
    axes[i].set_xlabel('Date')
    axes[i].set_ylabel('Sales')
    axes[i].grid(True)

# Add overall title
fig.suptitle('Regional Sales Comparison')
plt.tight_layout()
plt.show()
