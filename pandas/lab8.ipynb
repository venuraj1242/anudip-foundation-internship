# %% [markdown]
#  ### Lab1:
#  Write a Pandas program to split the following data frame into groups based
# on Class and count the number of students in that particular class.Also generate
# a bar chart based on the result and explain the conclusion.
#  ### Input:
# student_data = pd.DataFrame({
# 'school_code': ['s001','s002','s003','s001','s002','s004'],
# 'class': ['V', 'VI', 'VI', 'VI', 'V', 'VI'],
# 'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill',
# 'David Parkes'],
# 'age': [12, 12, 13, 13, 14, 12],
# 'height': [173, 192, 186, 167, 151, 159],
# 'weight': [35, 32, 33, 30, 31, 32],
# 'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},

# %%
import pandas as pd 
student_data = pd.DataFrame({
'school_code': ['s001','s002','s003','s001','s002','s004'],
'class': ['V', 'VI', 'VI', 'VI', 'V', 'VI'],
'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill',
'David Parkes'],
'age': [12, 12, 13, 13, 14, 12],
'height': [173, 192, 186, 167, 151, 159],
'weight': [35, 32, 33, 30, 31, 32],
'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
)
# Group by 'class' and count the number of students
print("original data:")
print(student_data)
print()
print("class wise no of student count")
print(student_data['class'].value_counts())
student_data['class'].value_counts().plot(kind='bar')
# Out:
# original data:
#   school_code class            name  age  height  weight  address
# 0        s001     V  Alberto Franco   12     173      35  street1
# 1        s002    VI    Gino Mcneill   12     192      32  street2
# 2        s003    VI     Ryan Parkes   13     186      33  street3
# 3        s001    VI    Eesha Hinton   13     167      30  street1
# 4        s002     V    Gino Mcneill   14     151      31  street2
# 5        s004    VI    David Parkes   12     159      32  street4
#
# class wise no of student count
# class
# VI    4
# V     2
# Name: count, dtype: int64
# <Axes: xlabel='class'>

# %% [markdown]
# ### Lab2:
#  Write a Pandas program to split the following dataframe by school
# code and get mean, min, and max value of age for each school.
# Also generate a horizontal bar chart based on the result and explain the
# conclusion.
# ### Input:
# student_data = pd.DataFrame({
# 'school_code': ['s001','s002','s003','s001','s002','s004'],
# 'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
# 'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill',
# 'David Parkes'],
# 'age': [12, 12, 13, 13, 14, 12],
# 'height': [173, 192, 186, 167, 151, 159],
# 'weight': [35, 32, 33, 30, 31, 32],
# 'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Input data
student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
})
print("original data")
print(student_data)
# Grouping the data by 'school_code' and calculating mean, min, and max of 'age'
age_stats = student_data['age'].groupby(student_data['school_code']).agg(['mean', 'min', 'max'])

print(age_stats)

# Plotting the results
age_stats.plot(kind='barh')
plt.xlabel('Age')
plt.ylabel('School Code')
plt.title('Mean, Min, and Max Age by School Code')
plt.show()
# Out:
# original data
#   school_code class            name  age  height  weight  address
# 0        s001     V  Alberto Franco   12     173      35  street1
# 1        s002     V    Gino Mcneill   12     192      32  street2
# 2        s003    VI     Ryan Parkes   13     186      33  street3
# 3        s001    VI    Eesha Hinton   13     167      30  street1
# 4        s002     V    Gino Mcneill   14     151      31  street2
# 5        s004    VI    David Parkes   12     159      32  street4
#              mean  min  max
# school_code
# s001         12.5   12   13
# s002         13.0   12   14
# s003         13.0   13   13
# s004         12.0   12   12

# %% [markdown]
# ### Lab3:
#  Write a Pandas program to split a dataset, group by one column and
# get mean, min, and max values by group. Using the following dataset find
# the mean, min, and max values of purchase amount (purch_amt) group bycustomer id (customer_id).Also generate a line chart based on the result and
# explain the conclusion.
# ### Input:
# orders_data = pd.DataFrame({
# 'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,
# 70013],
# 'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45,
# 75.29,3045.6],
# 'ord_date':
# ['2012-10-05','2012-09-10','2012-10-05','2012-08-17','2012-09-10','2012-07-27','2012-
# 09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
# 'customer_id':[3005,3001,3002,3009,3005,3007,3002,3004,3009,3008,3003,3002],
# 'salesman_id': [5002,5005,5001,5003,5002,5001,5001,5006,5003,5002,5007,5001]})

# %%
import pandas as pd
import matplotlib.pyplot as plt
orders_data = pd.DataFrame({
'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45,75.29,3045.6],
'ord_date':['2012-10-05','2012-09-10','2012-10-05','2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3005,3001,3002,3009,3005,3007,3002,3004,3009,3008,3003,3002],
'salesman_id': [5002,5005,5001,5003,5002,5001,5001,5006,5003,5002,5007,5001]})
df = pd.DataFrame(orders_data)

print("original data")
print(df)
# Group by 'customer_id' and calculate statistics
customer_stats = df['purch_amt'].groupby(df['customer_id']).agg(['mean', 'min', 'max'])
print(customer_stats)

# Create line chart
customer_stats.plot(kind='bar', figsize=(10, 6), title='Purchase Amount Statistics by Customer')
plt.xlabel('Customer ID')
plt.ylabel('Purchase Amount')
plt.show()
# Out:
# original data
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  2012-10-05         3005         5002
# 1    70009     270.65  2012-09-10         3001         5005
# 2    70002      65.26  2012-10-05         3002         5001
# 3    70004     110.50  2012-08-17         3009         5003
# 4    70007     948.50  2012-09-10         3005         5002
# 5    70005    2400.60  2012-07-27         3007         5001
# 6    70008    5760.00  2012-09-10         3002         5001
# 7    70010    1983.43  2012-10-10         3004         5006
# 8    70003    2480.40  2012-10-10         3009         5003
# 9    70012     250.45  2012-06-27         3008         5002
# 10   70011      75.29  2012-08-17         3003         5007
# 11   70013    3045.60  2012-04-25         3002         5001
#                     mean      min      max
# customer_id
# 3001          270.650000   270.65   270.65
# 3002         2956.953333    65.26  5760.00
# ...

# %% [markdown]
# ### Lab4:
#  Write a Pandas program to split the following data frame into groups
# and calculate monthly purchase amount.Also generate a bar chart based on
# the result and explain the conclusion.
# ### Input:
# df = pd.DataFrame({
# 'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,
# 70013],
# 'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45,
# 75.29,3045.6],
# 'ord_date':
# ['05-10-2012','09-10-2012','05-10-2012','08-17-2012','10-09-2012','07-27-2012','10-09-
# 2012','10-10-2012','10-10-2012','06-17-2012','07-08-2012','04-25-2012'],
# 'customer_id':[3001,3001,3005,3001,3005,3001,3005,3001,3005,3001,3005,3005],'salesman_id': [5002,5005,5001,5003,5002,5001,5001,5006,5003,5002,5007,5001]})

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'ord_no': [70001, 70009, 70002, 70004, 70007, 70005, 70008, 70010, 70003, 70012, 70011, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['05-10-2012', '09-10-2012', '05-10-2012', '08-17-2012', '10-09-2012', '07-27-2012', '10-09-2012', '10-10-2012', '10-10-2012', '06-17-2012', '07-08-2012', '04-25-2012'],
    'customer_id': [3001, 3001, 3005, 3001, 3005, 3001, 3005, 3001, 3005, 3001, 3005, 3005],
    'salesman_id': [5002, 5005, 5001, 5003, 5002, 5001, 5001, 5006, 5003, 5002, 5007, 5001]
}

df = pd.DataFrame(data)
print("original data")
print(df)

df['ord_date'] = pd.to_datetime(df['ord_date'], format='mixed')

# Extract month from 'ord_date'
df['month'] = df['ord_date'].dt.month
purchase_amount = df['purch_amt'].groupby(df['ord_date']).agg(['sum'])
print(purchase_amount)

# Group by 'month' and calculate total purchase amount
monthly_purchase_amount = df['purch_amt'].groupby(df['month']).sum()

monthly_purchase_amount.plot(kind='line', figsize=(10, 6), title='Monthly Purchase Amount')
plt.xlabel('Month')
plt.ylabel('Total Purchase Amount')
plt.show()
# Out:
# original data
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  05-10-2012         3001         5002
# 1    70009     270.65  09-10-2012         3001         5005
# 2    70002      65.26  05-10-2012         3005         5001
# 3    70004     110.50  08-17-2012         3001         5003
# 4    70007     948.50  10-09-2012         3005         5002
# 5    70005    2400.60  07-27-2012         3001         5001
# 6    70008    5760.00  10-09-2012         3005         5001
# 7    70010    1983.43  10-10-2012         3001         5006
# 8    70003    2480.40  10-10-2012         3005         5003
# 9    70012     250.45  06-17-2012         3001         5002
# 10   70011      75.29  07-08-2012         3005         5007
# 11   70013    3045.60  04-25-2012         3005         5001
#                 sum
# ord_date
# 2012-04-25  3045.60
# 2012-05-10   215.76
# 2012-06-17   250.45
# 2012-07-08    75.29
# 2012-07-27  2400.60
# 2012-08-17   110.50
# ...

# %% [markdown]
# ### ChatGPT Exercise
# Using ChatGPT generate the python code to solve the same problem
# Scenario:Analyzing E-commerce Customer Behavior
# Suppose you work for an e-commerce company, and you have a dataset containing
# information about customer behavior on your website. The dataset includes data on
# customer visits, product views, purchases, and more. You want to perform data analysis
# like Calculate the total number of unique customers,Calculate the total number of
# visits,Calculate the average number of products viewed per visit,Identify the most
# viewed product,Calculate the total revenue, Visualize the daily visit trend using Pandas
# to gain insights into customer behavior.Further, you need to get some inference out of the chart.
# Create a ChatGPT prompt to generate the code for this scenario. Based on the code
# generated, ask ChatGPT to give the conclusion/inference.
# Note. You can provide the data to ChatGPT in the form of a list or dictionary or ask it to
# use sample data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'CustomerID': [101, 102, 101, 103, 102, 104, 101, 103],
    'VisitDate': ['2023-11-01', '2023-11-02', '2023-11-03', '2023-11-01', '2023-11-04', '2023-11-05', '2023-11-03', '2023-11-06'],
    'ProductID': ['P1', 'P2', 'P3', 'P1', 'P2', 'P4', 'P1', 'P5'],
    'Revenue': [100, 150, 200, 80, 120, 50, 90, 70]
}

df = pd.DataFrame(data)

# Convert 'VisitDate' to datetime format
df['VisitDate'] = pd.to_datetime(df['VisitDate'])

# Calculate total number of unique customers
total_customers = df['CustomerID'].nunique()
print("Total number of unique customers:", total_customers)

# Calculate total number of visits
total_visits = len(df)
print("Total number of visits:", total_visits)

# Calculate average number of products viewed per visit
average_products_per_visit = df.groupby('VisitDate')['ProductID'].nunique().mean()
print("Average number of products viewed per visit:", average_products_per_visit)

# Identify the most viewed product
most_viewed_product = df['ProductID'].value_counts().idxmax()
print("Most viewed product:", most_viewed_product)

# Calculate total revenue
total_revenue = df['Revenue'].sum()
print("Total revenue:", total_revenue)

# Visualize daily visit trend
df['VisitDate'].value_counts().plot(kind='bar', title='Daily Visit Trend')
plt.xlabel('Visit Date')
plt.ylabel('Number of Visits')
plt.show()

# Conclusion
print("\nInsights:")
print("- The total number of unique customers and visits provide an overview of the website's reach.")
print("- The average number of products viewed per visit indicates customer engagement.")
print("- The most viewed product helps identify popular items.")
print("- The daily visit trend chart shows fluctuations in website traffic over time.")
print("- Further analysis can be done to identify peak visiting days, customer segmentation based on purchase behavior, and product recommendations.")
# Out:
# Total number of unique customers: 4
# Total number of visits: 8
# Average number of products viewed per visit: 1.1666666666666667
# Most viewed product: P1
# Total revenue: 860
# Insights:
# - The total number of unique customers and visits provide an overview of the website's reach.
# - The average number of products viewed per visit indicates customer engagement.
# - The most viewed product helps identify popular items.
# - The daily visit trend chart shows fluctuations in website traffic over time.
# - Further analysis can be done to identify peak visiting days, customer segmentation based on purchase behavior, and product recommendations.
