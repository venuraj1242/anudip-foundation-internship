# %% [markdown]
# calculate the total revenue generated by two product categories in a store

# %%
import numpy as np
category1_revenue = np. array([500,600,700,550])
category2_revenue = np. array([450,700,800,600])
print("total revenue :",category1_revenue+category2_revenue)
# Out:
# total revenue : [ 950 1300 1500 1150]

# %% [markdown]
# calculate the profit made by a company

# %%
revenue= np. array([10000,12000,11000,10500])
expenses=np.array([4000,5000,4500,4800])
print("profit:",revenue-expenses)
# Out:
# profit: [6000 7000 6500 5700]

# %% [markdown]
# detemine which product in a store are out of stock (quantity is 0)

# %%
inventory=np.array([10,0,5,0,20,0])
print("out of stock:",inventory[inventory==0])
# Out:
# out of stock: [0 0 0]

# %% [markdown]
# cal the total cost of item in a shopping cart , consider the quantity and price per item

# %%
quantity = np.array([2,3,4,1])
price_per_item=np.array([10.0,5.0,8.0,12.0])
print("total_cost_ of item:",quantity*price_per_item)
# Out:
# total_cost_ of item: [20. 15. 32. 12.]
